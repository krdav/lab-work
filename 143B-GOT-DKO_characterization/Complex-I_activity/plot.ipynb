# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf
import matplotlib.colors as mcolors
palette = list(mcolors.TABLEAU_COLORS.keys())
# %matplotlib inline

# %%
#sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="ticks", palette="muted")
sns.set_context("talk")

# %%
#sns.color_palette(as_cmap=True)

# %%
df = pd.read_excel('plotting_data.xlsx')

# %%
df
# Out:
#    UCPH     Percent
# 0     0  102.793598
# 1     0   97.206402
# 2     0  100.729775
# 3     0   99.270225
# 4     5   83.095288
# 5     5   83.913678
# 6     5   91.129190
# 7     5   82.480887

# %%
g1 = sns.barplot(x="UCPH", y="Percent", data=df, capsize=.1, errwidth=2, edgecolor='black', linewidth=2.5, alpha=0.7)

g1.set_ylabel('Complex I activity\n(norm. to 0 μM UCPH)');
g1.set_xlabel('UCPH (μM)');

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(6, 5))

g1 = sns.barplot(x="UCPH", y="Percent", data=df, capsize=.1, errwidth=2, edgecolor='black', linewidth=2.5, alpha=0.7)

g1.set_ylabel('Complex I activity\n(norm. to 0 μM UCPH)');
g1.set_xlabel('UCPH (μM)');


fig.tight_layout()
fig.savefig('2xGOT-KO_CI-activity_UCPH.pdf', bbox_inches='tight')
