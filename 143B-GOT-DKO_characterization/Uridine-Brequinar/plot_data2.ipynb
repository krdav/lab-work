# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf
import matplotlib.colors as mcolors
palette = list(mcolors.TABLEAU_COLORS.keys())
# %matplotlib inline

# %%
#sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="ticks", palette="muted")
sns.set_context("talk")

# %%
data_file = 'results_flat.xlsx'
df = pd.read_excel(data_file)

# %%
df
# Out:
#     Proliferation rate Cell line               Drug  Replicate
# 0             1.094020        #7            Vec/Vec          1
# 1             1.094329        #7            Vec/Vec          2
# 2             1.082528        #7            Vec/Vec          3
# 3             1.121744        #7        Uridine/Vec          1
# 4             1.067110        #7        Uridine/Vec          2
# 5             1.258976        #7        Uridine/Vec          3
# 6            -0.551835        #7      Vec/Brequinar          1
# 7            -0.500436        #7      Vec/Brequinar          2
# 8            -0.472067        #7      Vec/Brequinar          3
# 9             1.010285        #7  Uridine/Brequinar          1
# 10            1.002303        #7  Uridine/Brequinar          2
# 11            0.994496        #7  Uridine/Brequinar          3
# 12            1.044134       #10            Vec/Vec          1
# 13            1.029114       #10            Vec/Vec          2
# ...

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(9, 4))

g1 = sns.barplot(ax=ax1, y='Proliferation rate', x='Cell line', hue='Drug', ci=95, data=df, capsize=.04, errwidth=2, edgecolor='black', linewidth=2.5, alpha=0.7)

#g1.set_yscale('log')
g1.set_ylabel('Doublings per day');
#g1.set_xlabel('2xGOT KO clone');
g1.set_xlabel('GOT DKO clone');
g1.ticklabel_format(axis='y', style='sci', scilimits=[0, 0])
g1.legend(loc='upper left', bbox_to_anchor=(1.04, 1), borderaxespad=0, title='Drug')
g1.grid(True, axis='y')


plt.tight_layout()
fig.savefig('2xGOT-KO_uridine-brequinar.pdf')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 4))

mask = df['Cell line'] == '#7'
g1 = sns.barplot(ax=ax1, y='Cells', x='Cell line', hue='Time', ci=95, data=df[mask], capsize=.04, errwidth=2, edgecolor='black', linewidth=2.5, alpha=0.7)

g1.set_ylabel('Cell count');
g1.set_xlabel('GOT DKO clone #7');
g1.ticklabel_format(axis='y', style='sci', scilimits=[0, 0])
g1.get_legend().remove()
g1.set_xticks([])


mask = df['Cell line'] == '#10'
g2 = sns.barplot(ax=ax2, y='Cells', x='Cell line', hue='Time', ci=95, data=df[mask], capsize=.04, errwidth=2, edgecolor='black', linewidth=2.5, alpha=0.7)

g2.set_ylabel('Cell count');
g2.set_xlabel('GOT DKO clone #10');
g2.ticklabel_format(axis='y', style='sci', scilimits=[0, 0])
g2.legend(loc='upper left', bbox_to_anchor=(1.04, 1), borderaxespad=0, title='Asp depl. (h) ')
g2.set_xticks([])




plt.tight_layout()
fig.savefig('Asp-depletion-repletion-recovery.pdf')
