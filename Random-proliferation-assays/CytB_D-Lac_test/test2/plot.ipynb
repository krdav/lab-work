# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf
import matplotlib.colors as mcolors
palette = list(mcolors.TABLEAU_COLORS.keys())
# %matplotlib inline

# %%
#sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="ticks", palette="muted")
sns.set_context("talk")

# %%
#sns.color_palette(as_cmap=True)

# %%
df = pd.read_excel('plotting_data.xlsx')

# %%
df.head(3)
# Out:
#     Treatment  Pyruvate     Prlfr
# 0  20 mM NaCl         0 -0.373098
# 1  20 mM NaCl         0 -0.414604
# 2  20 mM NaCl         0 -0.347419

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(7.5, 5.4))

g1 = sns.barplot(ax=ax1, x="Treatment", y="Prlfr", hue='Pyruvate', data=df, linewidth=1, edgecolor='0.3')

g1.set_title('143B CytB')
g1.set_ylabel('Doublings per day')
g1.set_xlabel('')
g1.set_xticklabels(g1.get_xticklabels(), rotation=30, ha='right', minor=False, rotation_mode='anchor');
g1.grid(axis='y')
g1.hlines(0, -0.4, 2.4, color='black', alpha=0.6, linewidth=1.7)
sns.move_legend(g1, "upper left", bbox_to_anchor=(1, 1), title='Pyruvate (uM)')



fig.tight_layout()
fig.savefig('CytB_D-Lac_Prlfr.pdf', bbox_inches='tight')

# %%
df_metab = pd.read_excel('plotting_data_metab.xlsx')

# %%
df_metab.head()
# Out:
#       Media condition  Pyruvate
# 0         20 mM D-Lac  8.892457
# 1         20 mM D-Lac  8.866593
# 2  20 mM D-Lac (red.)  1.364617
# 3  20 mM D-Lac (red.)  1.382792

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(3, 5))

g1 = sns.barplot(ax=ax1, x="Media condition", y="Pyruvate", data=df_metab, linewidth=1, edgecolor='0.3')

#g1.set_title('143B CytB')
g1.set_ylabel('Pyruvate content (uM)')
g1.set_xlabel('')
g1.set_xticklabels(g1.get_xticklabels(), rotation=30, ha='right', minor=False, rotation_mode='anchor');
g1.grid(axis='y')


fig.tight_layout()
fig.savefig('D-Lac_reduced.pdf', bbox_inches='tight')
