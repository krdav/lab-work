# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf
import matplotlib.colors as mcolors
palette = list(mcolors.TABLEAU_COLORS.keys())
# %matplotlib inline

# %%
#sns.set_theme(style="ticks", palette="pastel")
sns.set_theme(style="ticks", palette="muted")
sns.set_context("talk")

# %%
#sns.color_palette(as_cmap=True)

# %%
df = pd.read_excel('plotting_data.xlsx')

# %%
df
# Out:
#     Proliferation_rate Chloramphenicol           Treatment
# 0             1.357564         Vehicle             Vehicle
# 1             1.333077         Vehicle             Vehicle
# 2             1.319598         Vehicle             Vehicle
# 3             1.144127              31             Vehicle
# 4             1.141158              31             Vehicle
# 5             1.116422              31             Vehicle
# 6             1.087902              63             Vehicle
# 7             1.028911              63             Vehicle
# 8             1.050947              63             Vehicle
# 9             1.088979             125             Vehicle
# 10            1.057997             125             Vehicle
# 11            1.100553             125             Vehicle
# 12            1.074108             250             Vehicle
# 13            1.032600             250             Vehicle
# 14            1.013678             250             Vehicle
# ...

# %%
g1 = sns.barplot(x="Chloramphenicol", y="Proliferation_rate", hue="Treatment", data=df, capsize=.1, errwidth=2, edgecolor='black', linewidth=2.5, alpha=0.7)

g1.set_ylabel('Doublings per day');
g1.set_xlabel(None);

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(11, 5))

g1 = sns.barplot(x="Chloramphenicol", y="Proliferation_rate", hue="Treatment", data=df, capsize=.1, errwidth=2, edgecolor='black', linewidth=2.5, alpha=0.7)

g1.set_ylabel('Doublings per day');
g1.set_xlabel('Chloramphenicol (μM)');


old_legend = g1.legend_
handles = old_legend.legendHandles
labels = [t.get_text() for t in old_legend.get_texts()]
title = old_legend.get_title().get_text()
g1.legend(handles, labels, title=title, bbox_to_anchor=(1.04,1), borderaxespad=0)



fig.tight_layout()
fig.savefig('2xGOT-KO_Chlor-gradient.pdf', bbox_inches='tight')
